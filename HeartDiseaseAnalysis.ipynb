# %% [markdown]
# # **Heart disease** or **Cardiovascular disease (CVD)**
# **Heart disease** or **Cardiovascular disease (CVD)** is a class of diseases that involve the heart or blood vessels. Cardiovascular diseases are the leading cause of death globally. This is true in all areas of the world except Africa. Together CVD resulted in 17.9 million deaths (32.1%) in 2015.  Deaths, at a given age, from CVD are more common and have been increasing in much of the developing world, while rates have declined in most of the developed world since the 1970s.
#
# So, in this kernel, I have conducted **Exploratory Data Analysis** or **EDA** of the heart disease dataset. **Exploratory Data Analysis** or **EDA** is a critical first step in analyzing a new dataset. The primary objective of EDA is to analyze the data for distribution, outliers and anomalies in the dataset. It enable us to direct specific testing of the hypothesis. It includes analysing the data to find the distribution of data, its main characteristics, identifying patterns and visualizations.  It also provides tools for hypothesis generation by visualizing and understanding the data through graphical representation.

# %% [markdown]
# ## `1.Importing Libraries`

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk(r'C:\Users\akash\OneDrive\Desktop\FSDS\EDA\25th, 26th- Advanced EDA project\EDA- HEALTHCARE DOMAIN'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\akash\OneDrive\Desktop\FSDS\EDA\25th, 26th- Advanced EDA project\EDA- HEALTHCARE DOMAIN\extensive-analysis-visualization-with-python.ipynb
# C:\Users\akash\OneDrive\Desktop\FSDS\EDA\25th, 26th- Advanced EDA project\EDA- HEALTHCARE DOMAIN\heart.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp

# %matplotlib inline
sns.set(style='whitegrid')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## `2.Import Data Set`

# %%
heart = pd.read_csv(r'C:\Users\akash\OneDrive\Desktop\FSDS\EDA\25th, 26th- Advanced EDA project\EDA- HEALTHCARE DOMAIN\heart.csv')

# %% [markdown]
# ## `3.Exploratory Data Analysis`

# %% [markdown]
# ### Check the  data set

# %%
print('The shape of the data set', heart.shape)
# Out:
# The shape of the data set (303, 14)

# %% [markdown]
# ### Preview the dataset

# %%
heart.head() # Top 5 rows
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### Summary of dataset

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# #### Dataset description <a class="anchor" id="6.4"></a>
#
# - The dataset contains several columns which are as follows -
#
#   - age : age in years
#   - sex : (1 = male; 0 = female)
#   - cp : chest pain type
#   - trestbps : resting blood pressure (in mm Hg on admission to the hospital)
#   - chol : serum cholestoral in mg/dl
#   - fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#   - restecg : resting electrocardiographic results
#   - thalach : maximum heart rate achieved
#   - exang : exercise induced angina (1 = yes; 0 = no)
#   - oldpeak : ST depression induced by exercise relative to rest
#   - slope : the slope of the peak exercise ST segment
#   - ca : number of major vessels (0-3) colored by flourosopy
#   - thal : 3 = normal; 6 = fixed defect; 7 = reversable defect
#   - target : 1 or 0

# %% [markdown]
# ### check dataTypes

# %%
heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### statistical property of dataset

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### view columns

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ## `4.Univariate Analysis`

# %% [markdown]
# ### check the no. of unique value in `target` variable

# %%
heart.target.nunique()
# Out:
# 2

# %%
heart['target'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### Frequency distribution of `target` variable

# %%
heart['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# ### Visualise frequency distribution of `target` variable

# %%
f, ax = plt.subplots(figsize=(4,5))
ax = sns.countplot(data = heart, x = 'target')
plt.show()

# %% [markdown]
# ### frequency distribution of `target` wrt `sex`

# %%
heart.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize = (8,6))
ax = sns.countplot(data = heart, x = 'sex', hue = 'target')
plt.show()

# %% [markdown]
# ### Alternatively we can visualise same information as follows

# %%
ax = sns.catplot(
    x = 'target', col = 'sex',
    data = heart, kind = 'count',
    height = 5, aspect=1, hue = 'target'
)

# %%
plt.show()

# %%
ax = sns.countplot(data=heart, y = 'target', hue = 'sex')
plt.show()

# %%
f, ax = plt.subplots(figsize = (8,6))
ax = sns.countplot(data = heart, x = 'target', palette = 'Set3')
plt.show()

# %% [markdown]
# ### *we can use `plt.bar` keyword arguments for a different look*

# %%
f, ax = plt.subplots(figsize = (8,6))
ax = sns.countplot(
    data = heart, x = 'target', facecolor = (0,0,0,0),
    linewidth = 5, edgecolor = sns.color_palette('dark', 3)
)
plt.show()

# %% [markdown]
# ### Visualise frequency distribution of `target` wrt `fbs` and `exang`

# %%
ax = sns.countplot(data = heart, x = 'target', hue = 'fbs')
plt.show()

# %%
ax = sns.countplot(data = heart, x = 'target', hue ='exang')
plt.show()

# %% [markdown]
# ## `5.Bivariate Analysis`

# %%
correlation = heart.corr()

# %% [markdown]
# The target variable is `target`. So, we should check how each attribute correlates with the `target` variable. We can do it as follows:-

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# ### Analysis of `target` and `cp` variable
# #### Explore `cp` variable
#
#
# - `cp` stands for chest pain type.
#
# - First, I will check number of unique values in `cp` variable.

# %%
heart['cp'].nunique()
# Out:
# 4

# %%
heart['cp'].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# So, there are 4 unique values in `cp` variable. Hence, it is a categorical variable.
#
# Now, I will view its frequency distribution as follows :

# %%
heart['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %% [markdown]
# #### Visualize the frequency distribution of `cp` variable

# %%
ax = sns.countplot(data = heart, x = 'cp', palette = 'Set1')
plt.show()

# %% [markdown]
# #### Frequency distribution of `target` variable wrt `cp`

# %%
heart.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
ax = sns.countplot(data = heart, x = 'cp', hue = 'target')
plt.show()

# %% [markdown]
# Alternatively, we can visualize the same information as follows :

# %%
ax = sns.catplot(
    data = heart, x = 'cp', hue = 'target', col = 'target',
    kind = 'count', height = 8, aspect=1
)
plt.show()

# %%
ax = sns.catplot(
    data = heart, x = 'target', col = 'cp', hue = 'target',
    kind = 'count', height = 8, aspect=1
)
plt.show()

# %% [markdown]
# ### Analysis of `target` and `thalach` variable <a class="anchor" id="8.3"></a>
#
# #### Explore `thalach` variable
#
#
# - `thalach` stands for maximum heart rate achieved.
#
# - I will check number of unique values in `thalach` variable as follows :

# %%
heart['thalach'].nunique()
# Out:
# 91

# %%
heart['thalach'].unique()
# Out:
# array([150, 187, 172, 178, 163, 148, 153, 173, 162, 174, 160, 139, 171,
#        144, 158, 114, 151, 161, 179, 137, 157, 123, 152, 168, 140, 188,
#        125, 170, 165, 142, 180, 143, 182, 156, 115, 149, 146, 175, 186,
#        185, 159, 130, 190, 132, 147, 154, 202, 166, 164, 184, 122, 169,
#        138, 111, 145, 194, 131, 133, 155, 167, 192, 121,  96, 126, 105,
#        181, 116, 108, 129, 120, 112, 128, 109, 113,  99, 177, 141, 136,
#         97, 127, 103, 124,  88, 195, 106,  95, 117,  71, 118, 134,  90])

# %% [markdown]
# ### visualize the frequency distribution of `thalach`

# %%
sns.distplot(heart['thalach'], bins = 10)
plt.show()

# %% [markdown]
# - We can see that the `thalach` variable is slightly negatively skewed.

# %% [markdown]
# We can use Pandas series object to get an informative axis label as follows :

# %%
x = heart['thalach']
x = pd.Series(x, name = 'thalach variable')
ax = sns.distplot(x, bins = 10)
plt.show()

# %% [markdown]
# we can plot the graph vertically

# %%
f, ax = plt.subplots(figsize=(6,5))
x = heart['thalach']
ax = sns.distplot(x, bins=10, vertical=True)
plt.show()

# %% [markdown]
# #### Seaborn Kernel Density Estimation (KDE) Plot
#
#
# - The kernel density estimate (KDE) plot is a useful tool for plotting the shape of a distribution.
#
# - The KDE plot plots the density of observations on one axis with height along the other axis.
#
# - We can plot a KDE plot as follows :

# %%
x = pd.Series(heart['thalach'], name = 'thalach variable')
ax = sns.kdeplot(x = heart['thalach'])
plt.show()

# %% [markdown]
# We can shade under the density curve and use a different color as follows:

# %%
f, ax = plt.subplots(figsize = (6,5))
x = heart['thalach']
x = pd.Series(x, name = 'thalach variable')
ax = sns.kdeplot(x, shade = True, color = 'r')
plt.show()

# %% [markdown]
# #### Histogram
#
# - A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# - We can plot a histogram as follows :

# %%
f, ax = plt.subplots(figsize = (6,5))
ax = sns.distplot(heart['thalach'], kde = False, rug = True, bins = 10)
plt.show()

# %%
ax = sns.displot(heart['thalach'], bins = 10, rug = True)
plt.show()

# %% [markdown]
# #### Visualize frequency distribution of `thalach` variable wrt `target`

# %%
f, ax = plt.subplots(figsize=(7,6))
ax = sns.stripplot(data = heart, x = 'target', y = 'thalach', palette = 'Set2')
plt.show()

# %% [markdown]
# #### Interpretation
#
# - We can see that those people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %% [markdown]
# We can add jitter to bring out the distribution of values as follows :

# %%
f, ax = plt.subplots(figsize=(7,6))
ax = sns.stripplot(data = heart, x = 'target', y = 'thalach', jitter=0.01, palette = 'Set2')
plt.show()

# %% [markdown]
# #### Visualize distibution of `thalach` wrt `target` with botplot

# %%
f, ax = plt.subplots(figsize = (7,6))
sns.boxplot(data = heart, x = 'target', y= 'thalach',  palette = 'Set1')
plt.show()

# %% [markdown]
# #### Interpretation
#
# The above boxplot confirms our finding that people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %% [markdown]
# ### Findings of Bivariate Analysis <a class="anchor" id="8.4"></a>
#
# Findings of Bivariate Analysis are as follows –
#
#
# - There is no variable which has strong positive correlation with `target` variable.
#
# - There is no variable which has strong negative correlation with `target` variable.
#
# - There is no correlation between `target` and `fbs`.
#
# - The `cp` and `thalach` variables are mildly positively correlated with `target` variable.
#
# - We can see that the `thalach` variable is slightly negatively skewed.
#
# - The people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).
#
# - The people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %% [markdown]
# ## `6.Multivariate Analysis`

# %% [markdown]
# ### Discover patterns and relationships
#
# - An important step in EDA is to discover patterns and relationships between variables in the dataset.
# - I will use `heat map` and `pair plot` to discover the patterns and relationships in the dataset.
# - First of all, I will draw a `heat map`.

# %% [markdown]
# ## Heat Map

# %%
plt.figure(figsize=(10,8))
plt.title('Correlation Heatmap of Heart disease Dataset')
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation = 90)
a.set_yticklabels(a.get_yticklabels(), rotation = 360)
plt.show()

# %% [markdown]
# #### Interpretation
#
# From the above correlation heat map, we can conclude that :-
#
# - `target` and `cp` variable are mildly positively correlated (correlation coefficient = 0.43).
# - `target` and `thalach` variable are also mildly positively correlated (correlation coefficient = 0.42).
# - `target` and `slope` variable are weakly positively correlated (correlation coefficient = 0.35).
# - `target` and `exang` variable are mildly negatively correlated (correlation coefficient = -0.44).
# - `target` and `oldpeak` variable are also mildly negatively correlated (correlation coefficient = -0.43).
# - `target` and `ca` variable are weakly negatively correlated (correlation coefficient = -0.39).
# - `target` and `thal` variable are also waekly negatively correlated (correlation coefficient = -0.34).

# %% [markdown]
# ## Pair Plot

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(
    heart[num_var], kind='scatter', 
    diag_kind = 'hist',hue='target',palette='cubehelix')
plt.show()

# %% [markdown]
# #### Comment
#
# - I have defined a variable `num_var`. Here `age`, `trestbps`, ``chol`, `thalach` and `oldpeak``
# - are numerical variables and `target` is the categorical variable.
# - So, I wll check relationships between these variables.

# %% [markdown]
# ### Analysis of `age` and other variables
# ### Check No. of unique value in `age` variable

# %%
heart['age'].nunique()
# Out:
# 41

# %%
heart['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %% [markdown]
# #### Interpretation
#
# - The mean value of the `age` variable is 54.37 years.
# - The minimum and maximum values of `age` are 29 and 77 years.

# %% [markdown]
# #### Plot the distribution of `age` variable
#
# Now, I will plot the distribution of `age` variable to view the statistical properties.

# %%
f, ax = plt.subplots(figsize=(7,6))
ax = sns.distplot(heart.age, bins=10)
plt.show() # the age distibution approximately normal

# %% [markdown]
# ### Analysis of `age` and `target` feature

# %% [markdown]
# Visualize frequency distribution `age` wrt `target` variable

# %%
plt.figure(figsize = (7,6))
sns.stripplot(data = heart, x = 'target', y = 'age', hue = 'target')
plt.show()

# %% [markdown]
# ## boxplot

# %%
plt.figure(figsize = (8,6))
sns.boxplot(data = heart, x = 'target', y = 'age', hue = 'target')
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above boxplot tells two different things :
#
#   - The mean age of the people who have heart disease is less than the mean age of the people who do not have heart disease.
#
#   - The dispersion or spread of age of the people who have heart disease is greater than the dispersion or spread of age of the people who do not have heart disease.

# %% [markdown]
# ### Analyze `age` and `trestbps` variable

# %% [markdown]
# #### Visualize the relationship between `age` and `trestbps` variable with scatterplot

# %%
plt.figure(figsize =(7,6))
sns.scatterplot(data = heart, x = 'age', y = 'trestbps')
plt.show()

# %% [markdown]
# there is `No Correlation` between `age` and `trestbps`

# %%
sns.regplot(data = heart, x = 'age', y = 'trestbps')
plt.show()

# %% [markdown]
# - The above line shows that linear regression model is not good fit to the data.

# %% [markdown]
# ## Analyse `age` and `chol`

# %%
sns.scatterplot(data = heart, x = 'age', y = 'chol')
plt.show()

# %%
sns.regplot(data = heart, x = 'age', y = 'chol')
plt.show()

# %% [markdown]
# - The above plot confirms that there is a slighly positive correlation between `age` and `chol` variables.

# %% [markdown]
# ## Analyze `chol` and `thalach` variable

# %%
sns.scatterplot(data = heart, x = 'chol', y = 'thalach')
plt.show()

# %%
sns.regplot(data = heart, x = 'chol', y = 'thalach')
plt.show()

# %% [markdown]
# - The above plot shows that there is no correlation between `chol` and `thalach` variable.

# %% [markdown]
# ## `7. Dealing with Missing values`

# %%
# checking for missing values

heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# We can see that there are no missing values in the dataset.

# %% [markdown]
# ## `8.Check with ASSERT statement`
#
# - We must confirm that our dataset has no missing values.
# - We can write an **assert statement** to verify this.
# - We can use an assert statement to programmatically check that no missing, unexpected 0 or negative values are present.
# - This gives us confidence that our code is running properly.
#
# - **Assert statement** will return nothing if the value being tested is true and will throw an AssertionError if the value is false.
#
# - **Asserts**
#
#   - assert 1 == 1 (return Nothing if the value is True)
#   - assert 1 == 2 (return AssertionError if the value is False)

# %%
# assert that there is no missing value in dataframe

assert pd.notnull(heart).all().all()

# %%
# assert all values greater than or equal to 0
assert (heart >= 0).all().all()

# %% [markdown]
# #### Interpretation
#
# - The above two commands do not throw any error. Hence, it is confirmed that there are no missing or negative values in the dataset.
# - All the values are greater than or equal to zero.

# %% [markdown]
# ## `9.Outlier detection`
# I will make boxplots to visualise outliers in the continuous numerical variables : -
#
# `age`, `trestbps`, `chol`, `thalach` and  `oldpeak` variables.

# %% [markdown]
# ## age variable

# %%
heart['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %% [markdown]
# ## Boxplot of age variable

# %%
sns.boxplot(x=heart['age'])
plt.show()

# %% [markdown]
# ## trestbps variable

# %%
heart['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %% [markdown]
# ## boxplot of trestbps

# %%
sns.boxplot(x = heart['trestbps'])
plt.show()

# %% [markdown]
# ## chol variable

# %%
heart['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %% [markdown]
# ## boxplot of chol variable

# %%
sns.boxplot(x = heart.chol)
plt.show()

# %% [markdown]
# ## thalach varianle

# %%
heart.thalach.describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %% [markdown]
# ## boxplot of thalach variable

# %%
sns.boxplot(x = heart['thalach'])
plt.show()

# %% [markdown]
# ## oldpeak variable

# %%
heart['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %% [markdown]
# ## boxplot of oldpeak

# %%
sns.boxplot(x = heart.oldpeak)
plt.show()

# %% [markdown]
# #### Findings
#
# - The `age` variable does not contain any outlier.
# - `trestbps` variable contains outliers to the right side.
# - `chol` variable also contains outliers to the right side.
# - `thalach` variable contains a single outlier to the left side.
# - `oldpeak` variable contains outliers to the right side.
# - Those variables containing outliers needs further investigation.

# %% [markdown]
# ## 10. Conclusion
#
# our EDA journey has come to an end.
# In this kernel, we have explored the heart disease dataset. In this kernel, we have implemented many of the strategies presented in the book **Think Stats - Exploratory Data Analysis in Python by Allen B Downey** . The feature variable of interest is `target` variable. We have analyzed it alone and check its interaction with other variables. We have also discussed how to detect missing data and outliers.
